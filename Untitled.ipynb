# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#          KK  SRep_Rand_No_Part  Hill_Climb_No_Part  Annealing_No_Part  \
# 0     62051         1171481405           566039383          178357059
# 1    112071          269782203           218725923           87070807
# 2   1078601           36186715           263321239           74049759
# 3     16662          684118742            38176694          588571594
# 4    114864          115198108            17738234           74772880
# ..      ...                ...                 ...                ...
# 95   169657          132291183            40312145          678488865
# 96   120809          209921237            53066381          693549643
# 97   163140          422705328           225899214          220194300
# 98   412188          395806184           415704242           23062624
# 99   239867           59598333           270985559           94643341
#
#     Rep_Rand_Part  Hill_Climb_Part  Annealing_Part
# 0             179             1019             303
# ...

# %%
data.columns
# Out:
# Index(['KK', 'SRep_Rand_No_Part', 'Hill_Climb_No_Part', 'Annealing_No_Part',
#        'Rep_Rand_Part', 'Hill_Climb_Part', 'Annealing_Part'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
plt.plot(data['KK'],label = 'KK',linewidth="3.0")
plt.plot(data['SRep_Rand_No_Part'],label = 'Rep_Rand_No_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_No_Part'], label = 'Hill_Climb_No_Part',linewidth="3.0")
plt.plot(data['Annealing_No_Part'],label='Annealing_No_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Standard Residual")
plt.show()
plt.savefig("try1.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Rep_Rand_Part'],label = 'Rep_Rand_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_Part'], label = 'Hill_Climb_Part',linewidth="3.0")
plt.plot(data['Annealing_Part'],label='Annealing_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Residual with pre-partitioning")
plt.show()
#plt.savefig("try1.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(data['SRep_Rand_No_Part'],label = 'Rep_Rand_No_Part',linewidth="3.0")
plt.plot(data['Rep_Rand_Part'], label = 'Rep_Rand_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Repeated Random")
plt.show()
#plt.savefig("try1.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Hill_Climb_No_Part'],label = 'Hill_Climb_No_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_Part'], label = 'Hill_Climb_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Hill Climbing")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Annealing_No_Part'],label = 'Annealing_No_Part',linewidth="3.0")
plt.plot(data['Annealing_Part'], label = 'Annealing_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Annealing")
plt.show()

# %%
data = pd.read_csv("timing.csv")

# %%
data
# Out:
#           KK  SRep_Rand_No_Part  Hill_Climb_No_Part  Annealing_No_Part  \
# 0   0.001040           2.879888            0.972859           2.631198
# 1   0.001317           2.797504            1.366347           2.281941
# 2   0.000767           1.874688            0.729512           2.893785
# 3   0.000840           2.636117            0.967416           2.888950
# 4   0.000741           2.870564            0.724803           2.890384
# ..       ...                ...                 ...                ...
# 95  0.000851           2.892487            0.718787           1.921903
# 96  0.000518           2.906770            0.875488           2.918657
# 97  0.000936           2.598465            1.051488           1.899870
# 98  0.000700           2.026860            0.921251           2.803488
# 99  0.000769           2.880960            0.736728           1.944584
#
#     Rep_Rand_Part  Hill_Climb_Part  Annealing_Part
# 0       25.350017        21.055708       63.091655
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(data['KK'],label = 'KK',linewidth="3.0")
plt.plot(data['SRep_Rand_No_Part'],label = 'Rep_Rand_No_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_No_Part'], label = 'Hill_Climb_No_Part',linewidth="3.0")
plt.plot(data['Annealing_No_Part'],label='Annealing_No_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Standard Time")
plt.show()
plt.savefig("try1.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Rep_Rand_Part'],label = 'Rep_Rand_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_Part'], label = 'Hill_Climb_Part',linewidth="3.0")
plt.plot(data['Annealing_Part'],label='Annealing_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Prepartitioned Time")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data['SRep_Rand_No_Part'],label = 'Rep_Rand_No_Part',linewidth="3.0")
plt.plot(data['Rep_Rand_Part'], label = 'Rep_Rand_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Repeated Random Time")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Hill_Climb_No_Part'],label = 'Hill_Climb_No_Part',linewidth="3.0")
plt.plot(data['Hill_Climb_Part'], label = 'Hill_Climb_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Hill Climbing")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Annealing_No_Part'],label = 'Annealing_No_Part',linewidth="3.0")
plt.plot(data['Annealing_Part'], label = 'Annealing_Part',linewidth="3.0")
plt.legend(loc="upper left")
plt.title("Annealing")
plt.show()
